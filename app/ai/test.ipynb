# %%
from langchain_community.document_loaders import PyPDFLoader,Docx2txtLoader,UnstructuredPowerPointLoader,TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import ChatOpenAI , OpenAIEmbeddings
from langchain_chroma import Chroma
from langchain_classic.chains import create_retrieval_chain
from prompt.quiz_generation import quiz_prompt
import json

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %%
def read_file(url,ext):
    if ext == '.pdf':
        loader = PyPDFLoader(url)
    elif ext == '.docx':
        loader = Docx2txtLoader(url)
    elif ext == '.pptx':
        loader = UnstructuredPowerPointLoader(url)
    elif ext == '.txt':
        loader = TextLoader(url)
    else:
        raise ValueError("Unsupported file type")
    return loader.load()

# %%
doc= read_file(r"C:\Users\syedb\Downloads\Phases LearnForge – Adaptive AI Tutoring Platform.pdf",".pdf")

# %%
def divide_chunks(docs):
    splitter = RecursiveCharacterTextSplitter(chunk_size=800,chunk_overlap=50)
    chunks = splitter.split_documents(docs)
    return chunks

# %%
chunks = divide_chunks(doc)

# %%
len(chunks)
# Out:
# 13

# %%
embeddings = OpenAIEmbeddings()

# %%
vector_db = Chroma(
    collection_name="learnforge",
    embedding_function=embeddings,
    persist_directory="../../chroma_db"
)

# %%
chunks
# Out:
# [Document(metadata={'producer': 'Skia/PDF m151 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Phases LearnForge – Adaptive AI Tutoring Platform', 'source': 'C:\\Users\\syedb\\Downloads\\Phases LearnForge – Adaptive AI Tutoring Platform.pdf', 'total_pages': 13, 'page': 0, 'page_label': '1'}, page_content='Phase  1  –  Project  Setup  &  Architecture  \nDuration:  3–5  Days  \nObjectives  \n●  Setup  repositories  ●  Setup  Next.js  frontend  ●  Setup  Django  backend  ●  Configure  PostgreSQL  ●  Configure  Redis  ●  Configure  Celery  ●  Configure  ChromaDB  ●  Configure  Docker  environments  \nDeliverables  \n●  Working  development  environment  ●  CI/CD  setup  ●  Project  folder  structure  ●  Database  connection  established  \n \nPhase  2  –  Authentication  &  User  \nManagement\n \nDuration:  4–6  Days  \nObjectives  \n●  User  registration  ●  Login  ●  JWT  authentication  ●  Refresh  tokens  ●  Role  management  \nRoles'),
#  Document(metadata={'producer': 'Skia/PDF m151 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Phases LearnForge – Adaptive AI Tutoring Platform', 'source': 'C:\\Users\\syedb\\Downloads\\Phases LearnForge – Adaptive AI Tutoring Platform.pdf', 'total_pages': 13, 'page': 1, 'page_label': '2'}, page_content='●  Student  ●  Instructor  ●  Admin  \nDeliverables  \n●  Authentication  APIs  ●  Protected  routes  ●  User  profile  management  \n \nPhase  3  –  Course  Management  System  \nDuration:  5–7  Days  \nObjectives  \n●  Create  courses  ●  Edit  courses  ●  Delete  courses  ●  Enroll  students  ●  Course  dashboard  \nDeliverables  \n●  Course  CRUD  APIs  ●  Course  pages  ●  Enrollment  system  \n \nPhase  4  –  Document  Upload  &  RAG  \nFoundation\n \nDuration:  7–10  Days  \nObjectives  \n●  Upload  PDFs'),
#  Document(metadata={'producer': 'Skia/PDF m151 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Phases LearnForge – Adaptive AI Tutoring Platform', 'source': 'C:\\Users\\syedb\\Downloads\\Phases LearnForge – Adaptive AI Tutoring Platform.pdf', 'total_pages': 13, 'page': 2, 'page_label': '3'}, page_content='●  Upload  DOCX  ●  Upload  PPTX  ●  Text  extraction  ●  Chunking  system  ●  Embedding  generation  ●  ChromaDB  integration  \nDeliverables  \n●  File  processing  pipeline  ●  Vector  database  setup  ●  Search-ready  documents  \nComplexity  \n⭐⭐⭐⭐⭐  \nThis  is  one  of  the  most  important  phases.  \n \nPhase  5  –  AI  Tutor  Chat  System  \nDuration:  7–10  Days  \nObjectives  \n●  Chat  interface  ●  GPT  integration  ●  Context  retrieval  ●  Conversation  history  ●  Source  citations  \nFlow  \nStudent  Question  \n↓  \nRAG  Retrieval  \n↓'),
#  Document(metadata={'producer': 'Skia/PDF m151 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Phases LearnForge – Adaptive AI Tutoring Platform', 'source': 'C:\\Users\\syedb\\Downloads\\Phases LearnForge – Adaptive AI Tutoring Platform.pdf', 'total_pages': 13, 'page': 3, 'page_label': '4'}, page_content='GPT-4o  \n↓  \nAnswer  \n \nDeliverables  \n●  Fully  functional  AI  tutor  \n \nPhase  6  –  Quiz  Generation  Engine  \nDuration:  5–7  Days  \nObjectives  \n●  Generate  MCQs  ●  Generate  True/False  ●  Generate  Short  Answers  ●  Quiz  evaluation  \nDeliverables  \n●  Quiz  generation  API  ●  Quiz  interface  ●  Quiz  results  page  \n \nPhase  7  –  Flashcard  System  \nDuration:  4–6  Days  \nObjectives  \n●  Generate  flashcards  ●  Review  interface'),
#  Document(metadata={'producer': 'Skia/PDF m151 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Phases LearnForge – Adaptive AI Tutoring Platform', 'source': 'C:\\Users\\syedb\\Downloads\\Phases LearnForge – Adaptive AI Tutoring Platform.pdf', 'total_pages': 13, 'page': 4, 'page_label': '5'}, page_content='●  Save  flashcards  ●  Learning  history  \nDeliverables  \n●  Flashcard  dashboard  ●  Flashcard  generation  APIs  \n \nPhase  8  –  Adaptive  Learning  Engine  \nDuration:  7–10  Days  \nObjectives  \n●  Analyze  student  mistakes  ●  Identify  weak  areas  ●  Adjust  difficulty  ●  Generate  recommendations  \nExample  \nStudent  scores:  \nLinear  Algebra  =  40%  \nStatistics  =  85%  \nCalculus  =  35%  \n \nSystem  automatically:  \n●  Increases  Linear  Algebra  practice  ●  Increases  Calculus  practice  ●  Reduces  Statistics  questions  \nDeliverables  \n●  Adaptive  learning  logic  ●  Recommendation  engine'),
#  Document(metadata={'producer': 'Skia/PDF m151 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Phases LearnForge – Adaptive AI Tutoring Platform', 'source': 'C:\\Users\\syedb\\Downloads\\Phases LearnForge – Adaptive AI Tutoring Platform.pdf', 'total_pages': 13, 'page': 5, 'page_label': '6'}, page_content='Complexity  \n⭐⭐⭐⭐⭐  \n \nPhase  9  –  Spaced  Repetition  Engine  \nDuration:  3–4  Days  \nObjectives  \n●  Implement  SM-2  algorithm  ●  Review  scheduling  ●  Retention  tracking  \nDeliverables  \n●  Smart  flashcard  review  system  \n \nPhase  10  –  Video  Processing  &  Lecture  \nChat\n \nDuration:  6–8  Days  \nObjectives  \n●  Video  upload  ●  Whisper  transcription  ●  Transcript  storage  ●  Transcript  chunking  ●  Lecture  Q&A  \nFlow  \nVideo  Upload  \n↓'),
#  Document(metadata={'producer': 'Skia/PDF m151 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Phases LearnForge – Adaptive AI Tutoring Platform', 'source': 'C:\\Users\\syedb\\Downloads\\Phases LearnForge – Adaptive AI Tutoring Platform.pdf', 'total_pages': 13, 'page': 6, 'page_label': '7'}, page_content='Whisper  \n↓  \nTranscript  \n↓  \nRAG  \n↓  \nChat  \n \nDeliverables  \n●  Chat  with  lecture  recordings  \n \nPhase  11  –  Student  Analytics  Dashboard  \nDuration:  5–7  Days  \nObjectives  \n●  Quiz  performance  ●  Weak  areas  ●  Learning  streaks  ●  Flashcard  progress  \nDeliverables  \n●  Student  dashboard  ●  Visual  analytics  \n \nPhase  12  –  Instructor  Portal'),
#  Document(metadata={'producer': 'Skia/PDF m151 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Phases LearnForge – Adaptive AI Tutoring Platform', 'source': 'C:\\Users\\syedb\\Downloads\\Phases LearnForge – Adaptive AI Tutoring Platform.pdf', 'total_pages': 13, 'page': 7, 'page_label': '8'}, page_content='Duration:  6–8  Days  \nObjectives  \n●  Upload  syllabus  ●  Manage  courses  ●  Track  students  ●  Performance  reports  \nDeliverables  \n●  Instructor  dashboard  ●  Student  monitoring  \n \nPhase  13  –  Admin  Portal  \nDuration:  4–5  Days  \nObjectives  \n●  Manage  users  ●  Manage  courses  ●  Monitor  AI  usage  ●  Monitor  API  costs  \nDeliverables  \n●  Admin  dashboard  \n \nPhase  14  –  Notifications  &  Email  System  \nDuration:  2–3  Days  \nObjectives  \n●  Reminder  emails  ●  Review  notifications'),
#  Document(metadata={'producer': 'Skia/PDF m151 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Phases LearnForge – Adaptive AI Tutoring Platform', 'source': 'C:\\Users\\syedb\\Downloads\\Phases LearnForge – Adaptive AI Tutoring Platform.pdf', 'total_pages': 13, 'page': 8, 'page_label': '9'}, page_content='●  Quiz  completion  alerts  \nDeliverables  \n●  Email  automation  \n \nPhase  15  –  Testing  &  Optimization  \nDuration:  7–10  Days  \nObjectives  \n●  Unit  testing  ●  API  testing  ●  Load  testing  ●  Security  testing  ●  RAG  optimization  \nDeliverables  \n●  Stable  production  build  \n \nPhase  16  –  Deployment  &  Launch  \nDuration:  3–5  Days  \nObjectives  \n●  AWS  deployment  ●  Docker  deployment  ●  SSL  ●  Domain  setup  ●  Monitoring  \nDeliverables  \n●  Production  environment'),
#  Document(metadata={'producer': 'Skia/PDF m151 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Phases LearnForge – Adaptive AI Tutoring Platform', 'source': 'C:\\Users\\syedb\\Downloads\\Phases LearnForge – Adaptive AI Tutoring Platform.pdf', 'total_pages': 13, 'page': 9, 'page_label': '10'}, page_content='Total  Estimated  Timeline  \nPhase  Duration  \nSetup  &  Architecture  3–5  Days  \nAuthentication  4–6  Days  \nCourse  Management  5–7  Days  \nDocument  +  RAG  7–10  Days  \nAI  Tutor  7–10  Days  \nQuiz  Engine  5–7  Days  \nFlashcards  4–6  Days  \nAdaptive  Learning  7–10  Days  \nSpaced  Repetition  3–4  Days'),
#  Document(metadata={'producer': 'Skia/PDF m151 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Phases LearnForge – Adaptive AI Tutoring Platform', 'source': 'C:\\Users\\syedb\\Downloads\\Phases LearnForge – Adaptive AI Tutoring Platform.pdf', 'total_pages': 13, 'page': 10, 'page_label': '11'}, page_content='Video  Processing  6–8  Days  \nStudent  Dashboard  5–7  Days  \nInstructor  Portal  6–8  Days  \nAdmin  Portal  4–5  Days  \nNotifications  2–3  Days  \nTesting  7–10  Days  \nDeployment  3–5  Days  \nTotal  Development  Time  \nMVP  (Core  Features  Only)  \n●  Authentication  ●  Courses  ●  RAG  ●  AI  Tutor  ●  Quizes  ●  Flashcards  \n➡  6–8  Weeks  \nProduction  V1  \n●  Everything  above  ●  Adaptive  Learning  ●  Video  Chat  ●  Analytics'),
#  Document(metadata={'producer': 'Skia/PDF m151 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Phases LearnForge – Adaptive AI Tutoring Platform', 'source': 'C:\\Users\\syedb\\Downloads\\Phases LearnForge – Adaptive AI Tutoring Platform.pdf', 'total_pages': 13, 'page': 11, 'page_label': '12'}, page_content='●  Instructor  Portal  \n➡  10–14  Weeks  \nEnterprise  Version  \n●  Multi-tenancy  ●  Team  management  ●  Billing  ●  Advanced  analytics  ●  Mobile  apps  \n➡  4–6  Months  \nSuggested  Milestones  for  Employee  \nMilestone  1  (Week  1–2)  \n●  Setup  ●  Authentication  ●  Course  Management  \nMilestone  2  (Week  3–4)  \n●  Document  Upload  ●  ChromaDB  ●  RAG  Pipeline  \nMilestone  3  (Week  5–6)  \n●  AI  Tutor  ●  Quiz  Generation  ●  Flashcards  \nMilestone  4  (Week  7–8)  \n●  Adaptive  Learning  ●  Spaced  Repetition  \nMilestone  5  (Week  9–10)  \n●  Video  Processing  ●  Lecture  Chat  \nMilestone  6  (Week  11–12)  \n●  Dashboards'),
#  Document(metadata={'producer': 'Skia/PDF m151 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Phases LearnForge – Adaptive AI Tutoring Platform', 'source': 'C:\\Users\\syedb\\Downloads\\Phases LearnForge – Adaptive AI Tutoring Platform.pdf', 'total_pages': 13, 'page': 12, 'page_label': '13'}, page_content='●  Instructor  Portal  ●  Admin  Portal  \nMilestone  7  (Week  13–14)  \n●  Testing  ●  Optimization  ●  Deployment  ●  Production  Release')]

# %%
vector_db.add_documents(chunks)
# Out:
# ['e2aab6aa-0888-4f78-91a4-f9d05e10e396',
#  '6d7261e6-8e93-4c73-ac89-0bd19000c354',
#  '5133bbf3-920a-46c3-91b4-9a7303818e0d',
#  'bd226e3a-8fee-4f85-8e04-fafc1c159fec',
#  'a3610416-ab23-4628-941c-f02b20868f62',
#  '306d222a-ca11-4574-b151-80548f36c492',
#  'a013ef6a-ae69-4147-9b03-0d907a18c1ac',
#  'fcfcf01c-793a-4f7d-9b89-a764e36d5f84',
#  '544a24d4-bd3c-4a79-9409-5e3ff7fe308d',
#  '8f5b60de-1bda-4c43-841b-404213078b45',
#  'e862212b-a851-4bb1-9c2e-a23357f63c27',
#  'c3822ea7-70c5-4ab6-bbb3-0463282f500c',
#  'b16030f7-8b7e-474a-bf28-9b07ba2ef9a9']

# %%
llm = ChatOpenAI(model="gpt-4o-mini")

# %%
chunks
# Out:
# [Document(metadata={'producer': 'Skia/PDF m151 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Phases LearnForge – Adaptive AI Tutoring Platform', 'source': 'C:\\Users\\syedb\\Downloads\\Phases LearnForge – Adaptive AI Tutoring Platform.pdf', 'total_pages': 13, 'page': 0, 'page_label': '1'}, page_content='Phase  1  –  Project  Setup  &  Architecture  \nDuration:  3–5  Days  \nObjectives  \n●  Setup  repositories  ●  Setup  Next.js  frontend  ●  Setup  Django  backend  ●  Configure  PostgreSQL  ●  Configure  Redis  ●  Configure  Celery  ●  Configure  ChromaDB  ●  Configure  Docker  environments  \nDeliverables  \n●  Working  development  environment  ●  CI/CD  setup  ●  Project  folder  structure  ●  Database  connection  established  \n \nPhase  2  –  Authentication  &  User  \nManagement\n \nDuration:  4–6  Days  \nObjectives  \n●  User  registration  ●  Login  ●  JWT  authentication  ●  Refresh  tokens  ●  Role  management  \nRoles'),
#  Document(metadata={'producer': 'Skia/PDF m151 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Phases LearnForge – Adaptive AI Tutoring Platform', 'source': 'C:\\Users\\syedb\\Downloads\\Phases LearnForge – Adaptive AI Tutoring Platform.pdf', 'total_pages': 13, 'page': 1, 'page_label': '2'}, page_content='●  Student  ●  Instructor  ●  Admin  \nDeliverables  \n●  Authentication  APIs  ●  Protected  routes  ●  User  profile  management  \n \nPhase  3  –  Course  Management  System  \nDuration:  5–7  Days  \nObjectives  \n●  Create  courses  ●  Edit  courses  ●  Delete  courses  ●  Enroll  students  ●  Course  dashboard  \nDeliverables  \n●  Course  CRUD  APIs  ●  Course  pages  ●  Enrollment  system  \n \nPhase  4  –  Document  Upload  &  RAG  \nFoundation\n \nDuration:  7–10  Days  \nObjectives  \n●  Upload  PDFs'),
#  Document(metadata={'producer': 'Skia/PDF m151 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Phases LearnForge – Adaptive AI Tutoring Platform', 'source': 'C:\\Users\\syedb\\Downloads\\Phases LearnForge – Adaptive AI Tutoring Platform.pdf', 'total_pages': 13, 'page': 2, 'page_label': '3'}, page_content='●  Upload  DOCX  ●  Upload  PPTX  ●  Text  extraction  ●  Chunking  system  ●  Embedding  generation  ●  ChromaDB  integration  \nDeliverables  \n●  File  processing  pipeline  ●  Vector  database  setup  ●  Search-ready  documents  \nComplexity  \n⭐⭐⭐⭐⭐  \nThis  is  one  of  the  most  important  phases.  \n \nPhase  5  –  AI  Tutor  Chat  System  \nDuration:  7–10  Days  \nObjectives  \n●  Chat  interface  ●  GPT  integration  ●  Context  retrieval  ●  Conversation  history  ●  Source  citations  \nFlow  \nStudent  Question  \n↓  \nRAG  Retrieval  \n↓'),
#  Document(metadata={'producer': 'Skia/PDF m151 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Phases LearnForge – Adaptive AI Tutoring Platform', 'source': 'C:\\Users\\syedb\\Downloads\\Phases LearnForge – Adaptive AI Tutoring Platform.pdf', 'total_pages': 13, 'page': 3, 'page_label': '4'}, page_content='GPT-4o  \n↓  \nAnswer  \n \nDeliverables  \n●  Fully  functional  AI  tutor  \n \nPhase  6  –  Quiz  Generation  Engine  \nDuration:  5–7  Days  \nObjectives  \n●  Generate  MCQs  ●  Generate  True/False  ●  Generate  Short  Answers  ●  Quiz  evaluation  \nDeliverables  \n●  Quiz  generation  API  ●  Quiz  interface  ●  Quiz  results  page  \n \nPhase  7  –  Flashcard  System  \nDuration:  4–6  Days  \nObjectives  \n●  Generate  flashcards  ●  Review  interface'),
#  Document(metadata={'producer': 'Skia/PDF m151 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Phases LearnForge – Adaptive AI Tutoring Platform', 'source': 'C:\\Users\\syedb\\Downloads\\Phases LearnForge – Adaptive AI Tutoring Platform.pdf', 'total_pages': 13, 'page': 4, 'page_label': '5'}, page_content='●  Save  flashcards  ●  Learning  history  \nDeliverables  \n●  Flashcard  dashboard  ●  Flashcard  generation  APIs  \n \nPhase  8  –  Adaptive  Learning  Engine  \nDuration:  7–10  Days  \nObjectives  \n●  Analyze  student  mistakes  ●  Identify  weak  areas  ●  Adjust  difficulty  ●  Generate  recommendations  \nExample  \nStudent  scores:  \nLinear  Algebra  =  40%  \nStatistics  =  85%  \nCalculus  =  35%  \n \nSystem  automatically:  \n●  Increases  Linear  Algebra  practice  ●  Increases  Calculus  practice  ●  Reduces  Statistics  questions  \nDeliverables  \n●  Adaptive  learning  logic  ●  Recommendation  engine'),
#  Document(metadata={'producer': 'Skia/PDF m151 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Phases LearnForge – Adaptive AI Tutoring Platform', 'source': 'C:\\Users\\syedb\\Downloads\\Phases LearnForge – Adaptive AI Tutoring Platform.pdf', 'total_pages': 13, 'page': 5, 'page_label': '6'}, page_content='Complexity  \n⭐⭐⭐⭐⭐  \n \nPhase  9  –  Spaced  Repetition  Engine  \nDuration:  3–4  Days  \nObjectives  \n●  Implement  SM-2  algorithm  ●  Review  scheduling  ●  Retention  tracking  \nDeliverables  \n●  Smart  flashcard  review  system  \n \nPhase  10  –  Video  Processing  &  Lecture  \nChat\n \nDuration:  6–8  Days  \nObjectives  \n●  Video  upload  ●  Whisper  transcription  ●  Transcript  storage  ●  Transcript  chunking  ●  Lecture  Q&A  \nFlow  \nVideo  Upload  \n↓'),
#  Document(metadata={'producer': 'Skia/PDF m151 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Phases LearnForge – Adaptive AI Tutoring Platform', 'source': 'C:\\Users\\syedb\\Downloads\\Phases LearnForge – Adaptive AI Tutoring Platform.pdf', 'total_pages': 13, 'page': 6, 'page_label': '7'}, page_content='Whisper  \n↓  \nTranscript  \n↓  \nRAG  \n↓  \nChat  \n \nDeliverables  \n●  Chat  with  lecture  recordings  \n \nPhase  11  –  Student  Analytics  Dashboard  \nDuration:  5–7  Days  \nObjectives  \n●  Quiz  performance  ●  Weak  areas  ●  Learning  streaks  ●  Flashcard  progress  \nDeliverables  \n●  Student  dashboard  ●  Visual  analytics  \n \nPhase  12  –  Instructor  Portal'),
#  Document(metadata={'producer': 'Skia/PDF m151 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Phases LearnForge – Adaptive AI Tutoring Platform', 'source': 'C:\\Users\\syedb\\Downloads\\Phases LearnForge – Adaptive AI Tutoring Platform.pdf', 'total_pages': 13, 'page': 7, 'page_label': '8'}, page_content='Duration:  6–8  Days  \nObjectives  \n●  Upload  syllabus  ●  Manage  courses  ●  Track  students  ●  Performance  reports  \nDeliverables  \n●  Instructor  dashboard  ●  Student  monitoring  \n \nPhase  13  –  Admin  Portal  \nDuration:  4–5  Days  \nObjectives  \n●  Manage  users  ●  Manage  courses  ●  Monitor  AI  usage  ●  Monitor  API  costs  \nDeliverables  \n●  Admin  dashboard  \n \nPhase  14  –  Notifications  &  Email  System  \nDuration:  2–3  Days  \nObjectives  \n●  Reminder  emails  ●  Review  notifications'),
#  Document(metadata={'producer': 'Skia/PDF m151 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Phases LearnForge – Adaptive AI Tutoring Platform', 'source': 'C:\\Users\\syedb\\Downloads\\Phases LearnForge – Adaptive AI Tutoring Platform.pdf', 'total_pages': 13, 'page': 8, 'page_label': '9'}, page_content='●  Quiz  completion  alerts  \nDeliverables  \n●  Email  automation  \n \nPhase  15  –  Testing  &  Optimization  \nDuration:  7–10  Days  \nObjectives  \n●  Unit  testing  ●  API  testing  ●  Load  testing  ●  Security  testing  ●  RAG  optimization  \nDeliverables  \n●  Stable  production  build  \n \nPhase  16  –  Deployment  &  Launch  \nDuration:  3–5  Days  \nObjectives  \n●  AWS  deployment  ●  Docker  deployment  ●  SSL  ●  Domain  setup  ●  Monitoring  \nDeliverables  \n●  Production  environment'),
#  Document(metadata={'producer': 'Skia/PDF m151 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Phases LearnForge – Adaptive AI Tutoring Platform', 'source': 'C:\\Users\\syedb\\Downloads\\Phases LearnForge – Adaptive AI Tutoring Platform.pdf', 'total_pages': 13, 'page': 9, 'page_label': '10'}, page_content='Total  Estimated  Timeline  \nPhase  Duration  \nSetup  &  Architecture  3–5  Days  \nAuthentication  4–6  Days  \nCourse  Management  5–7  Days  \nDocument  +  RAG  7–10  Days  \nAI  Tutor  7–10  Days  \nQuiz  Engine  5–7  Days  \nFlashcards  4–6  Days  \nAdaptive  Learning  7–10  Days  \nSpaced  Repetition  3–4  Days'),
#  Document(metadata={'producer': 'Skia/PDF m151 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Phases LearnForge – Adaptive AI Tutoring Platform', 'source': 'C:\\Users\\syedb\\Downloads\\Phases LearnForge – Adaptive AI Tutoring Platform.pdf', 'total_pages': 13, 'page': 10, 'page_label': '11'}, page_content='Video  Processing  6–8  Days  \nStudent  Dashboard  5–7  Days  \nInstructor  Portal  6–8  Days  \nAdmin  Portal  4–5  Days  \nNotifications  2–3  Days  \nTesting  7–10  Days  \nDeployment  3–5  Days  \nTotal  Development  Time  \nMVP  (Core  Features  Only)  \n●  Authentication  ●  Courses  ●  RAG  ●  AI  Tutor  ●  Quizes  ●  Flashcards  \n➡  6–8  Weeks  \nProduction  V1  \n●  Everything  above  ●  Adaptive  Learning  ●  Video  Chat  ●  Analytics'),
#  Document(metadata={'producer': 'Skia/PDF m151 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Phases LearnForge – Adaptive AI Tutoring Platform', 'source': 'C:\\Users\\syedb\\Downloads\\Phases LearnForge – Adaptive AI Tutoring Platform.pdf', 'total_pages': 13, 'page': 11, 'page_label': '12'}, page_content='●  Instructor  Portal  \n➡  10–14  Weeks  \nEnterprise  Version  \n●  Multi-tenancy  ●  Team  management  ●  Billing  ●  Advanced  analytics  ●  Mobile  apps  \n➡  4–6  Months  \nSuggested  Milestones  for  Employee  \nMilestone  1  (Week  1–2)  \n●  Setup  ●  Authentication  ●  Course  Management  \nMilestone  2  (Week  3–4)  \n●  Document  Upload  ●  ChromaDB  ●  RAG  Pipeline  \nMilestone  3  (Week  5–6)  \n●  AI  Tutor  ●  Quiz  Generation  ●  Flashcards  \nMilestone  4  (Week  7–8)  \n●  Adaptive  Learning  ●  Spaced  Repetition  \nMilestone  5  (Week  9–10)  \n●  Video  Processing  ●  Lecture  Chat  \nMilestone  6  (Week  11–12)  \n●  Dashboards'),
#  Document(metadata={'producer': 'Skia/PDF m151 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Phases LearnForge – Adaptive AI Tutoring Platform', 'source': 'C:\\Users\\syedb\\Downloads\\Phases LearnForge – Adaptive AI Tutoring Platform.pdf', 'total_pages': 13, 'page': 12, 'page_label': '13'}, page_content='●  Instructor  Portal  ●  Admin  Portal  \nMilestone  7  (Week  13–14)  \n●  Testing  ●  Optimization  ●  Deployment  ●  Production  Release')]

# %%
docs = vector_db.similarity_search(
    query="Generate 10 MCQs for LearnForge in Phase 6",
    k=5
)

# %%
context = '\n'.join(doc.page_content for doc in docs)
print(context)
# Out:
# GPT-4o
# ↓
# Answer
#
# Deliverables
# ●  Fully  functional  AI  tutor
#
# Phase  6  –  Quiz  Generation  Engine
# Duration:  5–7  Days
# Objectives
# ●  Generate  MCQs  ●  Generate  True/False  ●  Generate  Short  Answers  ●  Quiz  evaluation
# Deliverables
# ●  Quiz  generation  API  ●  Quiz  interface  ●  Quiz  results  page
#
# Phase  7  –  Flashcard  System
# Duration:  4–6  Days
# Objectives
# ●  Generate  flashcards  ●  Review  interface
# Total  Estimated  Timeline
# Phase  Duration
# Setup  &  Architecture  3–5  Days
# Authentication  4–6  Days
# Course  Management  5–7  Days
# Document  +  RAG  7–10  Days
# AI  Tutor  7–10  Days
# Quiz  Engine  5–7  Days
# Flashcards  4–6  Days
# Adaptive  Learning  7–10  Days
# Spaced  Repetition  3–4  Days
# ●  Instructor  Portal  ●  Admin  Portal
# Milestone  7  (Week  13–14)
# ●  Testing  ●  Optimization  ●  Deployment  ●  Production  Release
# ●  Save  flashcards  ●  Learning  history
# Deliverables
# ●  Flashcard  dashboard  ●  Flashcard  generation  APIs
#
# Phase  8  –  Adaptive  Learning  Engine
# Duration:  7–10  Days
# Objectives
# ●  Analyze  student  mistakes  ●  Identify  weak  areas  ●  Adjust  difficulty  ●  Generate  recommendations
# Example
# Student  scores:
# Linear  Algebra  =  40%
# Statistics  =  85%
# Calculus  =  35%
#
# System  automatically:
# ●  Increases  Linear  Algebra  practice  ●  Increases  Calculus  practice  ●  Reduces  Statistics  questions
# Deliverables
# ●  Adaptive  learning  logic  ●  Recommendation  engine
# ●  Instructor  Portal
# ➡  10–14  Weeks
# Enterprise  Version
# ●  Multi-tenancy  ●  Team  management  ●  Billing  ●  Advanced  analytics  ●  Mobile  apps
# ➡  4–6  Months
# Suggested  Milestones  for  Employee
# Milestone  1  (Week  1–2)
# ●  Setup  ●  Authentication  ●  Course  Management
# Milestone  2  (Week  3–4)
# ●  Document  Upload  ●  ChromaDB  ●  RAG  Pipeline
# Milestone  3  (Week  5–6)
# ●  AI  Tutor  ●  Quiz  Generation  ●  Flashcards
# Milestone  4  (Week  7–8)
# ●  Adaptive  Learning  ●  Spaced  Repetition
# Milestone  5  (Week  9–10)
# ●  Video  Processing  ●  Lecture  Chat
# Milestone  6  (Week  11–12)
# ●  Dashboards

# %%
quiz_prompt
# Out:
# ChatPromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template='\n    Question:\n    {question}\n        You are an expert educational quiz generator for the LearnForge platform.\n\nYour task is to generate quizzes **ONLY** from the provided course context. Never use outside knowledge. If the requested information is not available in the provided context, state that there is insufficient information instead of inventing questions or answers.\n\n## Instructions\n\n1. Read the provided course context carefully.\n2. Determine the quiz type requested by the user.\n3. Determine the number of questions:\n\n   * If the user specifies a number, generate **exactly** that many questions.\n   * If the user does not specify a number, generate **exactly 5** questions.\n4. Determine the difficulty:\n\n   * If the user specifies a difficulty (Easy, Medium, Hard), generate questions using **exactly** that difficulty.\n   * If no difficulty is specified, use **Medium** difficulty.\n5. Questions should be:\n\n   * Grammatically correct.\n   * Clear and unambiguous.\n   * Based only on the supplied context.\n   * Non-repetitive.\n6. Return **ONLY valid JSON**.\n7. Do not include markdown.\n8. Do not wrap the JSON inside triple backticks.\n9. Do not include explanations, introductions, notes, or extra text.\n10. The response must contain only the JSON object.\n\n---\n\n## MCQ FORMAT\n\nIf the user requests Multiple Choice Questions (MCQs), return EXACTLY this JSON structure:\n\n{{\n"mcq": [\n{{\n"mcq": "Question statement here",\n"options": {{\n"a": "Option A",\n"b": "Option B",\n"c": "Option C",\n"d": "Option D"\n}},\n"answer": "Correct option text here"\n}}\n]\n}}\n\nRules:\n\n* Every MCQ must contain exactly four options.\n* Only one option must be correct.\n* The answer field must contain the full correct option text, not the option letter.\n* Do not generate duplicate questions.\n\n---\n\n## TRUE/FALSE FORMAT\n\nIf the user requests True/False questions, return EXACTLY this JSON structure:\n\n{{\n"true_false": [\n{{\n"statement": "Statement here",\n"correct": true\n}},\n{{\n"statement": "Statement here",\n"correct": false\n}}\n]\n}}\n\nRules:\n\n* The "correct" field must be a boolean (true or false).\n* Do not use the strings "True" or "False".\n\n---\n\n## SHORT ANSWER FORMAT\n\nIf the user requests Short Answer questions, return EXACTLY this JSON structure:\n\n{{\n"short_answers": [\n{{\n"statement": "Question here",\n"correct": "Correct answer here"\n}},\n{{\n"statement": "Question here",\n"correct": "Correct answer here"\n}}\n]\n}}\n\nRules:\n\n* Answers should be concise.\n* Do not generate unnecessarily long answers.\n* Every answer must be directly supported by the provided context.\n\n---\n\n## GENERAL RULES\n\n* Use ONLY information from the provided context.\n* Never hallucinate facts.\n* Never mix multiple quiz formats in one response.\n* Produce exactly one JSON object.\n* Produce exactly the requested number of questions.\n* Respect the requested difficulty exactly.\n* If difficulty is not specified, use Medium.\n* If question count is not specified, generate exactly 5 questions.\n* If the context does not contain enough information to generate the requested quiz, return:\n\n{{\n"error": "Insufficient information in the provided context to generate the requested quiz."\n}}\nContext:\n{context}\n'), additional_kwargs={})])

# %%
quiz_model = quiz_prompt|llm

# %%
response = quiz_model.invoke({
    "question":"Generate 10 MCQs for LearnForge in Phase 6",
    "context":context
})

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
data = json.loads(response.content)
print(data['mcq'])
# Out:
# [{'mcq': 'What is one of the objectives of Phase 6 in the LearnForge project?', 'options': {'a': 'Generate adaptive learning strategies', 'b': 'Generate MCQs', 'c': 'Develop mobile apps', 'd': 'Create an admin portal'}, 'answer': 'Generate MCQs'}, {'mcq': 'What is the estimated duration for completing the Quiz Generation Engine in Phase 6?', 'options': {'a': '3–5 Days', 'b': '4–6 Days', 'c': '5–7 Days', 'd': '7–10 Days'}, 'answer': '5–7 Days'}, {'mcq': 'Which deliverable is associated with Phase 6?', 'options': {'a': 'Flashcard dashboard', 'b': 'Quiz results page', 'c': 'Adaptive learning logic', 'd': 'Mobile apps'}, 'answer': 'Quiz results page'}, {'mcq': 'In Phase 6, what type of quiz evaluation is included as an objective?', 'options': {'a': 'Flashcard generation', 'b': 'Quiz evaluation', 'c': 'Learning history saving', 'd': 'Security testing'}, 'answer': 'Quiz evaluation'}, {'mcq': 'What is the primary focus of Phase 6 in the LearnForge development process?', 'options': {'a': 'Creating a flashcard system', 'b': 'AI tutor functionality', 'c': 'Quiz generation', 'd': 'Adaptive learning system'}, 'answer': 'Quiz generation'}]

# %%
docs = read_file(r"C:\Users\syedb\Downloads\MCQS for Direct and Indirect Addres.txt",".txt")
docs
# Out:
# [Document(metadata={'source': 'C:\\Users\\syedb\\Downloads\\MCQS for Direct and Indirect Addres.txt'}, page_content='MCQS for Direct and Indirect Addressing:\n\n1. Which instruction uses direct addressing?\n\nA) MOV AX,[BX]\nB) MOV AX,[2000h]\nC) MOV AX,BX\nD) MOV AX,5\n\nAnswer: B\n\n2. Which instruction uses indirect addressing?\n\nA) MOV AX,[3000h]\nB) MOV AX,[BX]\nC) MOV AX,3000h\nD) MOV AX,AX\n\nAnswer: B\n\n3. In direct addressing, the address is stored in:\n\nA) Register\nB) Instruction\nC) Stack\nD) Flags\n\nAnswer: B\n\n4. In indirect addressing, the address is stored in:\n\nA) Flags\nB) Instruction\nC) Register\nD) Memory only\n\nAnswer: C\n\n5. Which instruction accesses memory directly?\n\nA) MOV AX,BX\nB) MOV AX,[1500h]\nC) ADD AX,BX\nD) MOV AX,5\n\nAnswer: B\n\n6. Which instruction accesses memory indirectly?\n\nA) MOV AX,[SI]\nB) MOV AX,[2000h]\nC) MOV AX,10\nD) MOV AX,AX\n\nAnswer: A\n\n7. What does this instruction do?\nMOV AX,[4000h]\n\nA) AX = 4000h\nB) AX = contents of memory 4000h\nC) AX = address 4000h\nD) AX = BX + 4000h\n\nAnswer: B\n\n8. What does this instruction do?\nMOV AX,[BX]\n\nA) AX = BX\nB) BX = AX\nC) AX = contents of memory pointed by BX\nD) AX = address of BX\n\nAnswer: C\n\n9. Which is NOT direct addressing?\n\nA) MOV AX,[1000h]\nB) MOV BX,[data]\nC) MOV AX,[BX]\nD) MOV DX,[5000h]\n\nAnswer: C\n\n10. Which is NOT indirect addressing?\n\nA) MOV AX,[BX]\nB) MOV AX,[SI]\nC) MOV AX,[DI]\nD) MOV AX,[3000h]\n\nAnswer: D\n\n11. What does [] represent?\n\nA) Register\nB) Memory\nC) Constant\nD) Flag\n\nAnswer: B\n\n12. Which instruction loads address into AX?\n\nA) MOV AX,[data]\nB) MOV AX,data\nC) MOV AX,[BX]\nD) MOV AX,[2000h]\n\nAnswer: B\n\n13. Which instruction loads value into AX?\nA) MOV AX,[data]\nB) MOV AX,100\nC) MOV AX,5000\nD)All of these\n\nAnswer: B\n\n14. If BX = 2000h\nMOV AX,[BX]\n\nAX becomes:\n\nA) 2000h\nB) BX\nC) Contents of memory 2000h\nD) Address of BX\n\nAnswer: C\n\n15. Which addressing mode is used?\nMOV AX,[data]\n\nA) Indirect\nB) Direct\nC) Immediate\nD) Register\n\nAnswer: B\n\n16. Which addressing mode is used?\nMOV AX,[BX]\n\nA) Direct\nB) Indirect\nC) Immediate\nD) Register\n\nAnswer: B\n\n17. Which instruction uses a fixed address?\n\nA) MOV AX,[BX]\nB) MOV AX,[SI]\nC) MOV AX,[2500h]\nD) MOV AX,[DI]\n\nAnswer: C\n\n18. Which register is valid for indirect addressing?\n\nA) AH\nB) AL\nC) BX\nD) DH\n\nAnswer: C\n\n19. Which register cannot be used for indirect addressing?\n\nA) BX\nB) SI\nC) DI\nD) AH\n\nAnswer: D\n\n20. Which instruction reads memory?\n\nA) MOV AX,BX\nB) MOV AX,[BX]\nC) ADD AX,BX\nD) CMP AX,BX\n\nAnswer: B\n\n21. Which instruction writes memory?\n\nA) MOV AX,BX\nB) MOV [BX],AX\nC) ADD AX,BX\nD) CMP AX,BX\n\nAnswer: B\n\n22. Which instruction uses pointer concept?\n\nA) MOV AX,[BX]\nB) MOV AX,10\nC) MOV AX,BX\nD) ADD AX,BX\n\nAnswer: A\n\n23. Which is an example of array access?\nMOV AX,[data+BX]\n\nA) Direct\nB) Indirect\nC) Immediate\nD) Register\n\nAnswer: B\n\n24. If BX = 4\nMOV AX,[data+BX]\n\nMeans:\n\nA) First element\nB) Second element\nC) Third element\nD) Fourth element\n\nAnswer: C\n\n25. Which is direct addressing?\n\nA) MOV AX,[BX]\nB) MOV AX,[2000h]\nC) MOV AX,[SI]\nD) MOV AX,[DI]\n\nAnswer: B\n\n26. Which is indirect addressing?\n\nA) MOV AX,[1000h]\nB) MOV AX,[BX]\nC) MOV AX,data\nD) MOV AX,10\n\nAnswer: B\n\n27. Direct addressing is mainly used for:\n\nA) Arrays\nB) Loops\nC) Variables\nD) Flags\n\nAnswer: C\n\n28. Indirect addressing is mainly used for:\n\nA) Printing\nB) Arrays\nC) Interrupts\nD) Flags\n\nAnswer: B\n\n29. Which instruction uses memory operand?\n\nA) MOV AX,BX\nB) MOV AX,[BX]\nC) ADD AX,BX\nD) CMP AX,BX\n\nAnswer: B\n\n30. Which statement is correct?\n\nA) Direct addressing uses registers\nB) Indirect addressing uses fixed address\nC) Direct addressing uses fixed memory address\nD) Indirect addressing uses constants\n\nAnswer: C\n')]

# %%
chunks = divide_chunks(docs)
len(chunks)
# Out:
# 5

# %%
for chunk in chunks:
    chunk.metadata = {"course_id":3}

# %%
vector_db.add_documents(
    chunks
)
# Out:
# ['bb1bff22-eb8e-4af2-8d1f-09636a8fc96a',
#  'f79a02d0-ba73-47d8-a702-37a7231243c9',
#  'd44a0ad0-da1b-463f-a445-36bd99dce97c',
#  '53383342-90da-4a32-a38a-d14d2d42853e',
#  '0b46f616-0542-41f4-ad94-ff8558a29377']

# %%
doc = vector_db.similarity_search("LearnForge",k=4,filter={"course_id":{"$in":[3]}})

# %%
doc
# Out:
# [Document(id='f79a02d0-ba73-47d8-a702-37a7231243c9', metadata={'course_id': 3}, page_content='7. What does this instruction do?\nMOV AX,[4000h]\n\nA) AX = 4000h\nB) AX = contents of memory 4000h\nC) AX = address 4000h\nD) AX = BX + 4000h\n\nAnswer: B\n\n8. What does this instruction do?\nMOV AX,[BX]\n\nA) AX = BX\nB) BX = AX\nC) AX = contents of memory pointed by BX\nD) AX = address of BX\n\nAnswer: C\n\n9. Which is NOT direct addressing?\n\nA) MOV AX,[1000h]\nB) MOV BX,[data]\nC) MOV AX,[BX]\nD) MOV DX,[5000h]\n\nAnswer: C\n\n10. Which is NOT indirect addressing?\n\nA) MOV AX,[BX]\nB) MOV AX,[SI]\nC) MOV AX,[DI]\nD) MOV AX,[3000h]\n\nAnswer: D\n\n11. What does [] represent?\n\nA) Register\nB) Memory\nC) Constant\nD) Flag\n\nAnswer: B\n\n12. Which instruction loads address into AX?\n\nA) MOV AX,[data]\nB) MOV AX,data\nC) MOV AX,[BX]\nD) MOV AX,[2000h]\n\nAnswer: B'),
#  Document(id='53383342-90da-4a32-a38a-d14d2d42853e', metadata={'course_id': 3}, page_content='A) BX\nB) SI\nC) DI\nD) AH\n\nAnswer: D\n\n20. Which instruction reads memory?\n\nA) MOV AX,BX\nB) MOV AX,[BX]\nC) ADD AX,BX\nD) CMP AX,BX\n\nAnswer: B\n\n21. Which instruction writes memory?\n\nA) MOV AX,BX\nB) MOV [BX],AX\nC) ADD AX,BX\nD) CMP AX,BX\n\nAnswer: B\n\n22. Which instruction uses pointer concept?\n\nA) MOV AX,[BX]\nB) MOV AX,10\nC) MOV AX,BX\nD) ADD AX,BX\n\nAnswer: A\n\n23. Which is an example of array access?\nMOV AX,[data+BX]\n\nA) Direct\nB) Indirect\nC) Immediate\nD) Register\n\nAnswer: B\n\n24. If BX = 4\nMOV AX,[data+BX]\n\nMeans:\n\nA) First element\nB) Second element\nC) Third element\nD) Fourth element\n\nAnswer: C\n\n25. Which is direct addressing?\n\nA) MOV AX,[BX]\nB) MOV AX,[2000h]\nC) MOV AX,[SI]\nD) MOV AX,[DI]\n\nAnswer: B\n\n26. Which is indirect addressing?\n\nA) MOV AX,[1000h]\nB) MOV AX,[BX]\nC) MOV AX,data\nD) MOV AX,10'),
#  Document(id='0b46f616-0542-41f4-ad94-ff8558a29377', metadata={'course_id': 3}, page_content='Answer: B\n\n27. Direct addressing is mainly used for:\n\nA) Arrays\nB) Loops\nC) Variables\nD) Flags\n\nAnswer: C\n\n28. Indirect addressing is mainly used for:\n\nA) Printing\nB) Arrays\nC) Interrupts\nD) Flags\n\nAnswer: B\n\n29. Which instruction uses memory operand?\n\nA) MOV AX,BX\nB) MOV AX,[BX]\nC) ADD AX,BX\nD) CMP AX,BX\n\nAnswer: B\n\n30. Which statement is correct?\n\nA) Direct addressing uses registers\nB) Indirect addressing uses fixed address\nC) Direct addressing uses fixed memory address\nD) Indirect addressing uses constants\n\nAnswer: C'),
#  Document(id='bb1bff22-eb8e-4af2-8d1f-09636a8fc96a', metadata={'course_id': 3}, page_content='MCQS for Direct and Indirect Addressing:\n\n1. Which instruction uses direct addressing?\n\nA) MOV AX,[BX]\nB) MOV AX,[2000h]\nC) MOV AX,BX\nD) MOV AX,5\n\nAnswer: B\n\n2. Which instruction uses indirect addressing?\n\nA) MOV AX,[3000h]\nB) MOV AX,[BX]\nC) MOV AX,3000h\nD) MOV AX,AX\n\nAnswer: B\n\n3. In direct addressing, the address is stored in:\n\nA) Register\nB) Instruction\nC) Stack\nD) Flags\n\nAnswer: B\n\n4. In indirect addressing, the address is stored in:\n\nA) Flags\nB) Instruction\nC) Register\nD) Memory only\n\nAnswer: C\n\n5. Which instruction accesses memory directly?\n\nA) MOV AX,BX\nB) MOV AX,[1500h]\nC) ADD AX,BX\nD) MOV AX,5\n\nAnswer: B\n\n6. Which instruction accesses memory indirectly?\n\nA) MOV AX,[SI]\nB) MOV AX,[2000h]\nC) MOV AX,10\nD) MOV AX,AX\n\nAnswer: A\n\n7. What does this instruction do?\nMOV AX,[4000h]')]

# %%
from utils.global_utils import *

# %%
docs = read_file(r"C:\Users\syedb\Downloads\you.pdf")
chunks = divide_chunks(docs)
embeddings = get_embeddings()
vector_db = createOrGetChroma(embeddings)
add_docs(vector_db,chunks,3)

# %%
question = "Generate 10 mcqs about my self"
context = get_docs(vector_db,question,[3])

# %%
context
# Out:
# 'interest in cricket and table tennis keeps me physically active and mentally refreshed. \nI am determined to build a successful career in the field of Data Science while maintaining \nstrong personal values and a balanced lifestyle. With dedication, continuous learning, and hard \nwork, I am confident that I will achieve my goals and contribute positively to society.\nagriculture, business analytics, and artificial intelligence research. I believe data has the power \nto transform industries, improve decision-making, and create innovative solutions. \nI also aim to continuously upgrade my knowledge by learning new technologies and staying \nupdated with advancements in the field. In the modern world, adaptability and lifelong learning \nare essential for success, especially in technology-driven careers. \n \nPersonal Interests and Hobbies \nApart from academics, I strongly believe in maintaining a balanced lifestyle. I have a deep \ninterest in sports, particularly cricket and table tennis. Playing sports is not only a hobby for \nme but also a way to maintain physical fitness and mental relaxation.\nIntroduction \nMy name is Syed Basit Abbas Haider Zaidi, though I am commonly known as Basit. I am \ncurrently pursuing a Bachelor of Science in Data Science (BSDS) at Superior University in \nPakistan. I am a passionate, curious, and growth-oriented individual who believes in \ncontinuous learning and self-improvement. My academic journey, combined with my personal \ninterests and extracurricular activities, reflects my dedication to excellence and balanced \npersonal development. \nI strongly believe that education is not only about acquiring knowledge but also about building \ncharacter, discipline, and vision for the future. Throughout my academic career, I have always \naimed to develop both technical expertise and personal skills that will help me succeed \nprofessionally and socially.\nchallenging situations. Challenges are opportunities for growth, and I try to learn from every \nexperience. \nAnother strength of mine is adaptability. In today’s fast-changing technological world, the \nability to adapt to new tools and environments is crucial. As a Data Science student, I regularly \nlearn new programming languages, frameworks, and analytical techniques, which helps me \nstay flexible and future-oriented. \n \nVision for the Future \nLooking ahead, I envision myself as a skilled data professional contributing to innovative \nprojects in Pakistan and internationally. I want to use my knowledge to create solutions that'

# %%
quiz = generate_quiz(question,context)

# %%
quiz
# Out:
# {'type': 'short_answers',
#  'short_answers': [{'statement': 'What school did you complete your early schooling at?',
#    'correct': 'DPS School Lahore'},
#   {'statement': 'What was a significant aspect of your educational journey at DPS?',
#    'correct': 'It shaped my foundational knowledge and instilled discipline.'},
#   {'statement': 'Which two institutions did you attend after completing your schooling?',
#    'correct': 'KIPS Academy and Science College in Lahore.'},
#   {'statement': 'What personal quality do you consider one of your strongest?',
#    'correct': 'Determination.'},
#   {'statement': 'What is an essential skill you believe in maintaining as a university student?',
#    'correct': 'Time management.'}]}

# %%
context
# Out:
# 'challenging situations. Challenges are opportunities for growth, and I try to learn from every \nexperience. \nAnother strength of mine is adaptability. In today’s fast-changing technological world, the \nability to adapt to new tools and environments is crucial. As a Data Science student, I regularly \nlearn new programming languages, frameworks, and analytical techniques, which helps me \nstay flexible and future-oriented. \n \nVision for the Future \nLooking ahead, I envision myself as a skilled data professional contributing to innovative \nprojects in Pakistan and internationally. I want to use my knowledge to create solutions that\nagriculture, business analytics, and artificial intelligence research. I believe data has the power \nto transform industries, improve decision-making, and create innovative solutions. \nI also aim to continuously upgrade my knowledge by learning new technologies and staying \nupdated with advancements in the field. In the modern world, adaptability and lifelong learning \nare essential for success, especially in technology-driven careers. \n \nPersonal Interests and Hobbies \nApart from academics, I strongly believe in maintaining a balanced lifestyle. I have a deep \ninterest in sports, particularly cricket and table tennis. Playing sports is not only a hobby for \nme but also a way to maintain physical fitness and mental relaxation.\nMCQS for Direct and Indirect Addressing:\n\n1. Which instruction uses direct addressing?\n\nA) MOV AX,[BX]\nB) MOV AX,[2000h]\nC) MOV AX,BX\nD) MOV AX,5\n\nAnswer: B\n\n2. Which instruction uses indirect addressing?\n\nA) MOV AX,[3000h]\nB) MOV AX,[BX]\nC) MOV AX,3000h\nD) MOV AX,AX\n\nAnswer: B\n\n3. In direct addressing, the address is stored in:\n\nA) Register\nB) Instruction\nC) Stack\nD) Flags\n\nAnswer: B\n\n4. In indirect addressing, the address is stored in:\n\nA) Flags\nB) Instruction\nC) Register\nD) Memory only\n\nAnswer: C\n\n5. Which instruction accesses memory directly?\n\nA) MOV AX,BX\nB) MOV AX,[1500h]\nC) ADD AX,BX\nD) MOV AX,5\n\nAnswer: B\n\n6. Which instruction accesses memory indirectly?\n\nA) MOV AX,[SI]\nB) MOV AX,[2000h]\nC) MOV AX,10\nD) MOV AX,AX\n\nAnswer: A\n\n7. What does this instruction do?\nMOV AX,[4000h]\nmake processes more efficient and improve people’s lives. Whether it is through predictive \nmodeling, AI systems, or business analytics, I aim to make a meaningful impact. \nI also aspire to continue growing both professionally and personally. Success, for me, is not \nonly about career achievements but also about becoming a responsible, knowledgeable, and \ninspiring individual. I want to be someone who continuously learns, adapts, and strives for \nexcellence. \n \nConclusion \nIn conclusion, my journey from DPS School Lahore to KIPS Academy and now to Superior \nUniversity reflects my commitment to education and self-development. As a BSDS student, I \nam passionate about technology and data science. Alongside my academic pursuits, my'

# %%
vector_db.delete_collection()
